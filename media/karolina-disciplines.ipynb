# %%
import matplotlib.pyplot as plt

# %%
labels = [
    "materiálové vědy",
    "biovědy",
    "fyzika a astronomie",
    "vědy o Zemi",
    "počítačová věda",
    "matematika",
    "inženýrství"
]
fractions = [64, 18, 7, 6, 3, 1, 1]

# %%
plt.pie(fractions, colors=plt.cm.Dark2.colors)
plt.savefig("karolina-disciplines.pdf")
